# %%
import json
import os

def extract_json_data(folder_path):
    class_level_params = []
    method_level_params = {}
    num_tests = 0 # number of tests is same as num of files
    num_tests_using_configs = 0

    # Walk through all directories and subdirectories
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Check for JSON files
            if filename.endswith('.json'):
                file_path = os.path.join(root, filename)
                num_tests += 1
                with open(file_path, 'r') as f:
                    data = json.load(f)
                    
                    # Extract classLevelParams
                    class_level_params.extend(data.get("classLevelParams", []))
                    
                    test_class_uses_configs = bool(data.get("testClassUsesConfigs", []))
                    test_function_uses_configs = False
                    # Extract methodLevelParams and its values
                    for method, params in data.get("methodLevelParams", {}).items():
                        if len(params) > 0:
                            test_function_uses_configs = True
                        if method not in method_level_params:
                            method_level_params[method] = []
                        # Extend the list with values from the current method's parameters
                        method_level_params[method].extend(params)
                        
                    if test_class_uses_configs or test_function_uses_configs:
                        num_tests_using_configs += 1

    return class_level_params, method_level_params, num_tests, num_tests_using_configs


# List of JSON files to read
folder_path = "./flink"  # replace with actual file paths

class_level_params, method_level_params, num_tests, num_tests_using_configs = extract_json_data(folder_path)


configs = []
tests = []
num_tests_with_configs_f = 0 # stores the number of test functions that uses config values
for method, params in method_level_params.items():
    print(f"method: {method}, params: {params} , length: {len(params)}")
    if len(params) > 0:
        num_tests_with_configs_f += 1
    tests.append(method)
    configs.extend(params)
    
configs = list(set(configs))  
tests = list(set(tests))  
print(f"Number of Configurations :{len(configs)} ")
print(f"Number of Tests Files Executed :{num_tests}")
print(f"Number of Tests Files Using Configurations {num_tests_using_configs}")
# Out:
# method: org.apache.flink.datastream.impl.common.ValueTypeDescriptorTest_testValueTypeDescriptorNonValue, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.ValueTypeDescriptorTest_testValueTypeDescriptor, params: [] , length: 0
# method: org.apache.flink.datastream.impl.ExecutionEnvironmentImplTest_testFromSource, params: [] , length: 0
# method: org.apache.flink.datastream.impl.ExecutionEnvironmentImplTest_testSetExecutionMode, params: [] , length: 0
# method: org.apache.flink.datastream.impl.ExecutionEnvironmentImplTest_testAddWrapSource, params: [] , length: 0
# method: org.apache.flink.datastream.impl.ExecutionEnvironmentImplTest_testAddOperator, params: [] , length: 0
# method: org.apache.flink.datastream.impl.ExecutionEnvironmentImplTest_testSetContextExecutionEnvironment, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.TypeUtilsTest_testNewInstanceWithIncorrectConstructorArgType, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.TypeUtilsTest_testNewInstanceWithObjectArg, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.TypeUtilsTest_testNewInstanceWithIncorrectConstructorArgCount, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.TypeUtilsTest_testNewInstanceWithPrimitiveArg, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testProcess, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testStateErrorWithConnectKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testConnectKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testStateErrorWithOneInputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testStateErrorWithProcessTwoOutput, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testConnectBroadcastStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testStateErrorWithConnectBroadcastStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testPartitioning, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testConfig, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testProcessTwoOutput, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.KeyedPartitionStreamImplTest_testToSink, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultNonPartitionedContextTest_testApplyToAllPartitions, params: ['metrics.scope.tm', 'metrics.scope.tm-job', 'metrics.scope.operator', 'metrics.scope.jm', 'metrics.scope.jm-job', 'metrics.scope.jm-operator', 'metrics.scope.task'] , length: 7
# method: org.apache.flink.datastream.impl.context.DefaultNonPartitionedContextTest_testKeyedApplyToAllPartitions, params: [] , length: 0
# method: org.apache.flink.datastream.impl.operators.TwoInputBroadcastProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.operators.TwoInputBroadcastProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 24
# method: org.apache.flink.datastream.impl.attribute.StreamingJobGraphGeneratorWithAttributeTest_testPropagateAlongOperatorChain, params: [] , length: 0
# method: org.apache.flink.datastream.impl.attribute.StreamingJobGraphGeneratorWithAttributeTest_testNoOutputUntilEndOfInputWithOperatorChainCase1, params: [] , length: 0
# method: org.apache.flink.datastream.impl.attribute.StreamingJobGraphGeneratorWithAttributeTest_testTwoOutput, params: [] , length: 0
# method: org.apache.flink.datastream.impl.attribute.StreamingJobGraphGeneratorWithAttributeTest_testWithoutOperatorChain, params: [] , length: 0
# method: org.apache.flink.datastream.impl.operators.TwoOutputProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'chainIndex', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 25
# method: org.apache.flink.datastream.impl.operators.TwoOutputProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testGetOneInputKeyedTransformation, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testGetTwoInputOutputType, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testGetOneInputTransformation, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testLambdaMissingType, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testTwoOutputType, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testGetTwoInputTransformation, params: [] , length: 0
# method: org.apache.flink.datastream.impl.utils.StreamUtilsTest_testGetOneInputOutputType, params: [] , length: 0
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputBroadcastProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputBroadcastProcessOperatorTest_testCheckKey, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 24
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputBroadcastProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputNonBroadcastProcessOperatorTest_testCheckKey, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 24
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputNonBroadcastProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.operators.KeyedTwoInputNonBroadcastProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testToSink, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testParallelism, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testStateErrorWithTwoInputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testStateErrorWithOneInputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testStateErrorWithTwoOutputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testPartitioning, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.GlobalStreamImplTest_testConfig, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.BasicTypeDescriptorTest_testBasicTypeDescriptor, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultTaskInfoTest_testTaskInfo, params: [] , length: 0
# method: org.apache.flink.datastream.impl.operators.ProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'chainIndex', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 25
# method: org.apache.flink.datastream.impl.operators.ProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.operators.KeyedTwoOutputProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'chainIndex', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 25
# method: org.apache.flink.datastream.impl.operators.KeyedTwoOutputProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.operators.KeyedTwoOutputProcessOperatorTest_testKeyCheck, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultJobInfoTest_testGetExecutionMode, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultJobInfoTest_testGetJobName, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testProcessTwoOutput, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testConnectBroadcastStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testConnectNonKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testStateErrorWithConnectNonKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testProcess, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testPartitioning, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testStateErrorWithOneInputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testStateErrorWithConnectBroadcastStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testConfig, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testStateErrorWithTwoOutputStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.NonKeyedPartitionStreamImplTest_testToSink, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.BroadcastStreamImplTest_testConnectKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.BroadcastStreamImplTest_testStateErrorWithConnectKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.BroadcastStreamImplTest_testConnectKeyedStreamWithOutputKeySelector, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.BroadcastStreamImplTest_testStateErrorWithConnectNonKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.stream.BroadcastStreamImplTest_testConnectNonKeyedStream, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.MapTypeDescriptorTest_testMapTypeDescriptor, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.OutputCollectorTest_testCollect, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.OutputCollectorTest_testCollectAndOverwriteTimestamp, params: [] , length: 0
# method: org.apache.flink.datastream.impl.operators.TwoInputNonBroadcastProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 17
# method: org.apache.flink.datastream.impl.operators.TwoInputNonBroadcastProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 24
# method: org.apache.flink.datastream.impl.common.ListTypeDescriptorTest_testListTypeDescriptor, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testMapState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testBroadcastListState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testValueState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testGetCurrentKey, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testListState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testExecuteInKeyContext, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testBroadcastMapState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testReducingState, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testAggState, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'chainIndex', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 25
# method: org.apache.flink.datastream.impl.context.DefaultStateManagerTest_testErrorInGetCurrentKey, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.KeyCheckedOutputCollectorTest_testCollect, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.KeyCheckedOutputCollectorTest_testCollectAndOverwriteTimestamp, params: [] , length: 0
# method: org.apache.flink.datastream.impl.common.KeyCheckedOutputCollectorTest_testNotEqualToCurrentKey, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultProcessingTimeManagerTest_testCurrentProcessingTime, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultProcessingTimeManagerTest_testRegisterProcessingTimer, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultProcessingTimeManagerTest_testDeleteProcessingTimeTimer, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultTwoOutputNonPartitionedContextTest_testKeyedApplyToAllPartitions, params: [] , length: 0
# method: org.apache.flink.datastream.impl.context.DefaultTwoOutputNonPartitionedContextTest_testApplyToAllPartitions, params: ['metrics.scope.tm', 'metrics.scope.tm-job', 'metrics.scope.operator', 'metrics.scope.jm', 'metrics.scope.jm-job', 'metrics.scope.jm-operator', 'metrics.scope.task'] , length: 7
# method: org.apache.flink.datastream.impl.operators.KeyedProcessOperatorTest_testProcessRecord, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.datastream.impl.operators.KeyedProcessOperatorTest_testCheckKey, params: ['state.latency-track.state-name-as-variable', 'taskmanager.memory.managed.consumer-weights', 'metrics.scope.operator', 'state.latency-track.history-size', 'metrics.scope.task', 'metrics.latency.granularity', 'metrics.scope.tm', 'execution.checkpointing.storage', 'metrics.scope.jm-operator', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'state.backend.type', 'execution.checkpointing.checkpoints-after-tasks-finish', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.scope.jm', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'chainIndex', 'metrics.scope.tm-job', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.create-subdir', 'metrics.scope.jm-job', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression'] , length: 25
# method: org.apache.flink.datastream.impl.operators.KeyedProcessOperatorTest_testEndInput, params: ['state.latency-track.state-name-as-variable', 'execution.checkpointing.checkpoints-after-tasks-finish', 'taskmanager.memory.managed.consumer-weights', 'state.latency-track.history-size', 'execution.checkpointing.unaligned.enabled', 'state.changelog.enabled', 'metrics.latency.history-size', 'state.latency-track.sample-interval', 'metrics.latency.granularity', 'chainIndex', 'taskmanager.network.memory.buffer-debloat.period', 'execution.checkpointing.storage', 'execution.checkpointing.create-subdir', 'state.latency-track.keyed-state-enabled', 'managedMemFraction.STATE_BACKEND', 'execution.checkpointing.max-concurrent-checkpoints', 'execution.checkpointing.snapshot-compression', 'state.backend.type'] , length: 18
# method: org.apache.flink.connector.file.sink.compactor.operator.CompactorRequestTypeInfoTest_testGetTotalFields, params: [] , length: 0
# method: org.apache.flink.connector.file.sink.compactor.operator.CompactorRequestTypeInfoTest_testHashcodeAndEquals, params: [] , length: 0
# method: org.apache.flink.connector.file.sink.compactor.operator.CompactorRequestTypeInfoTest_testSerialization, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUpgradeTest_upgradedSerializerHasExpectedSchemaCompatibility, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUpgradeTest_restoreSerializerIsValid, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUpgradeTest_upgradedSerializerIsValidWhenCompatibleAsIs, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUpgradeTest_upgradedSerializerIsValidAfterMigration, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUpgradeTest_upgradedSerializerIsValidAfterReconfiguration, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testCopyIntoReusedElements, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testCopy, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializabilityAndEquals, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSnapshotConfigurationAndReconfigure, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testInstantiate, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializeIndividually, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializeAsSequenceNoReuse, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializedCopyIndividually, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testNullability, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializeAsSequenceReusingValues, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializeIndividuallyReusingValues, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testConfigSnapshotInstantiation, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testSerializedCopyAsSequence, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testCopyIntoNewElements, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testDuplicate, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testGetLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableSerializerUUIDTest_testCopyIndependently, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testNormalizedKeysGreatSmallFullLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testInequalityWithReference, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testDuplicate, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testInequality, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testNormalizedKeysGreatSmallAscDescHalfLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testKeyExtraction, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testNormalizedKeyReadWriter, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testEquality, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testNormalizedKeysEqualsHalfLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testNormalizedKeysEqualsFullLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorTest_testEqualityWithReference, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.WritableTypeInfoTest_testSerialization, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.WritableTypeInfoTest_testHashcodeAndEquals, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.WritableTypeInfoTest_testGetTotalFields, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testNormalizedKeysEqualsHalfLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testInequality, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testEquality, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testNormalizedKeysGreatSmallFullLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testNormalizedKeysEqualsFullLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testDuplicate, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testKeyExtraction, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testNormalizedKeysGreatSmallAscDescHalfLength, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testEqualityWithReference, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testNormalizedKeyReadWriter, params: [] , length: 0
# method: org.apache.flink.api.java.typeutils.runtime.WritableComparatorUUIDTest_testInequalityWithReference, params: [] , length: 0
# method: org.apache.flink.streaming.api.functions.sink.filesystem.bucketassigners.DateTimeBucketAssignerTest_testGetBucketPathWithSpecifiedTimezone, params: [] , length: 0
# method: org.apache.flink.streaming.api.functions.sink.filesystem.bucketassigners.DateTimeBucketAssignerTest_testGetBucketPathWithSpecifiedFormatString, params: [] , length: 0
# method: org.apache.flink.streaming.api.functions.sink.filesystem.OutputStreamBasedPartFileRecoverableMigrationTest_testSerializationPending, params: [] , length: 0
# method: org.apache.flink.streaming.api.functions.sink.filesystem.OutputStreamBasedPartFileRecoverableMigrationTest_testSerializationInProgress, params: [] , length: 0
# method: org.apache.flink.dropwizard.ScheduledDropwizardReporterTest_testAddingMetrics, params: [] , length: 0
# method: org.apache.flink.dropwizard.ScheduledDropwizardReporterTest_testInvalidCharacterReplacement, params: [] , length: 0
# method: org.apache.flink.dropwizard.ScheduledDropwizardReporterTest_testMetricCleanup, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MetricMapperTest_testMapMeter, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MetricMapperTest_testMapHistogram, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MetricMapperTest_testMapGauge, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MetricMapperTest_testMapCounter, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterFactoryTest_testWithoutArgument, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterFactoryTest_testMetricReporterSetupViaSPI, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterFactoryTest_testPortRangeArgument, params: [] , length: 0
# method: org.apache.flink.metrics.graphite.GraphiteReporterFactoryTest_testMetricReporterSetupViaSPI, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testGenerateTable, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testJMXAvailability, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testMeterReporting, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testReplaceInvalidChars, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testHistogramReporting, params: [] , length: 0
# method: org.apache.flink.metrics.jmx.JMXReporterTest_testPortConflictHandling, params: [] , length: 0
# method: org.apache.flink.metrics.otel.VariableNameUtilTest_getVariableName, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testAddHistogram, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testOnlyCounterRegistered, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testAddMeter, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testAddGauge, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testOnlyGaugeRegistered, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testSkipOnNoMetrics, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testOnlyMeterRegistered, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testFilterCharacters, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testOnlyHistogramRegistered, params: [] , length: 0
# method: org.apache.flink.metrics.slf4j.Slf4jReporterTest_testAddCounter, params: [] , length: 0
# method: org.apache.flink.metrics.otel.OpenTelemetryMetricAdapterTest_testMeter, params: [] , length: 0
# method: org.apache.flink.metrics.otel.OpenTelemetryMetricAdapterTest_testHistogram, params: [] , length: 0
# method: org.apache.flink.metrics.otel.OpenTelemetryMetricAdapterTest_testCounter, params: [] , length: 0
# method: org.apache.flink.metrics.otel.OpenTelemetryMetricAdapterTest_testGaugeLong, params: [] , length: 0
# method: org.apache.flink.metrics.otel.OpenTelemetryMetricAdapterTest_testGaugeDouble, params: [] , length: 0
# method: org.apache.flink.runtime.jobmanager.JMXJobManagerMetricTest_testJobManagerJMXMetricAccess, params: ['cluster.services.shutdown-timeout'] , length: 1
# method: org.apache.flink.dropwizard.metrics.FlinkCounterWrapperTest_testWrapperIncDec, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDMetersReportingOfNegativeValues, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testAddingMetrics, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDHistogramReporting, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testReplaceInvalidChars, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDGaugesReportingOfNegativeValues, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDCountersReportingOfNegativeValues, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDGaugesReporting, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDHistogramReportingOfNegativeValues, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDCountersReporting, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterTest_testStatsDMetersReporting, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTaskScopeTest_histogramsCanBeAddedSeveralTimesIfTheyDifferInLabels, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTaskScopeTest_countersCanBeAddedSeveralTimesIfTheyDifferInLabels, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTaskScopeTest_removingSingleInstanceOfMetricDoesNotBreakOtherInstances, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTaskScopeTest_gaugesCanBeAddedSeveralTimesIfTheyDifferInLabels, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTaskScopeTest_metersCanBeAddedSeveralTimesIfTheyDifferInLabels, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MeasurementInfoProviderTest_simpleTestGetMetricInfo, params: [] , length: 0
# method: org.apache.flink.metrics.influxdb.MeasurementInfoProviderTest_testNormalizingTags, params: [] , length: 0
# method: org.apache.flink.metrics.datadog.DCounterTest_testGetMetricValue, params: [] , length: 0
# method: org.apache.flink.metrics.statsd.StatsDReporterFactoryTest_testMetricReporterSetupViaSPI, params: [] , length: 0
# method: org.apache.flink.metrics.MeterViewTest_testGetRate, params: [] , length: 0
# method: org.apache.flink.metrics.MeterViewTest_testMarkEvent, params: [] , length: 0
# method: org.apache.flink.metrics.MeterViewTest_testTimeSpanBelowUpdateRate, params: [] , length: 0
# method: org.apache.flink.metrics.MeterViewTest_testGetCount, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_nullGaugeDoesNotBreakReporter, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_shortGaugeIsConvertedCorrectly, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_histogramIsReportedAsPrometheusSummary, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_counterIsReportedAsPrometheusGauge, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_cannotStartTwoReportersOnSamePort, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_metricIsRemovedWhileOtherMetricsWithSameNameExist, params: [] , length: 0
# method: org.apache.flink.metrics.prometheus.PrometheusReporterTest_gaugeIsReportedAsPrometheusGauge, params: [] , length: 0
# ...
# method: org.apache.flink.kubernetes.kubeclient.decorators.HadoopConfMountDecoratorTest_testPodWithHadoopConfVolume, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.decorators.HadoopConfMountDecoratorTest_testHadoopConfConfigMap, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.decorators.HadoopConfMountDecoratorTest_testExistingConfigMapPrecedeOverHadoopConfEnv, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.decorators.HadoopConfMountDecoratorTest_testExistingHadoopConfigMap, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.hadoop.conf.config-map.name', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 6
# method: org.apache.flink.kubernetes.kubeclient.decorators.HadoopConfMountDecoratorTest_testEmptyHadoopConfDirectory, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.decorators.InternalServiceDecoratorTest_testBuildAccompanyingKubernetesResources, params: ['kubernetes.transactional-operation.max-retry-delay', 'blob.server.port', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type', 'jobmanager.rpc.address', 'kubernetes.cluster-id', 'jobmanager.rpc.port'] , length: 9
# method: org.apache.flink.kubernetes.kubeclient.decorators.InternalServiceDecoratorTest_testDisableInternalService, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.resources.KubernetesLeaderElectorTest_testAnnotationMatched, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.resources.KubernetesLeaderElectorTest_testAnnotationNotMatch, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.resources.KubernetesLeaderElectorTest_testNoAnnotation, params: ['kubernetes.transactional-operation.max-retry-delay', 'kubernetes.transactional-operation.max-retries', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type'] , length: 5
# method: org.apache.flink.kubernetes.kubeclient.factory.KubernetesTaskManagerFactoryTest_testPod, params: ['kubernetes.transactional-operation.max-retry-delay', 'taskmanager.memory.process.size', 'taskmanager.memory.network.min', 'kubernetes.transactional-operation.max-retries', 'taskmanager.memory.jvm-metaspace.size', 'taskmanager.memory.task.off-heap.size', 'taskmanager.cpu.cores', 'external-resources', 'taskmanager.memory.network.fraction', 'taskmanager.memory.jvm-overhead.min', 'taskmanager.memory.jvm-overhead.fraction', 'taskmanager.memory.framework.off-heap.size', 'taskmanager.memory.network.max', 'taskmanager.memory.framework.heap.size', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type', 'taskmanager.numberOfTaskSlots', 'taskmanager.memory.jvm-overhead.max', 'taskmanager.memory.managed.fraction'] , length: 20
# method: org.apache.flink.kubernetes.kubeclient.factory.KubernetesTaskManagerFactoryTest_testContainer, params: ['kubernetes.transactional-operation.max-retry-delay', 'taskmanager.memory.process.size', 'taskmanager.memory.network.min', 'kubernetes.transactional-operation.max-retries', 'taskmanager.memory.jvm-metaspace.size', 'taskmanager.memory.task.off-heap.size', 'taskmanager.cpu.cores', 'external-resources', 'taskmanager.memory.network.fraction', 'taskmanager.memory.jvm-overhead.min', 'taskmanager.memory.jvm-overhead.fraction', 'taskmanager.memory.framework.off-heap.size', 'taskmanager.memory.network.max', 'taskmanager.memory.framework.heap.size', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type', 'taskmanager.numberOfTaskSlots', 'taskmanager.memory.jvm-overhead.max', 'taskmanager.memory.managed.fraction'] , length: 20
# method: org.apache.flink.kubernetes.kubeclient.factory.KubernetesTaskManagerFactoryTest_testHadoopDecoratorsCanBeTurnedOff, params: ['kubernetes.transactional-operation.max-retry-delay', 'taskmanager.memory.process.size', 'taskmanager.memory.network.min', 'kubernetes.transactional-operation.max-retries', 'taskmanager.memory.jvm-metaspace.size', 'taskmanager.memory.task.off-heap.size', 'taskmanager.cpu.cores', 'external-resources', 'taskmanager.memory.network.fraction', 'taskmanager.memory.jvm-overhead.min', 'taskmanager.memory.jvm-overhead.fraction', 'taskmanager.memory.framework.off-heap.size', 'taskmanager.memory.network.max', 'taskmanager.memory.framework.heap.size', 'kubernetes.namespace', 'kubernetes.transactional-operation.initial-retry-delay', 'kubernetes.rest-service.exposed.node-port-address-type', 'taskmanager.numberOfTaskSlots', 'taskmanager.memory.jvm-overhead.max', 'taskmanager.memory.managed.fraction'] , length: 20
# method: org.apache.flink.runtime.fs.hdfs.HadoopViewFileSystemTruncateTest_testViewFileSystemRecoverWorks, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.LimitedConnectionsConfigurationTest_testConfiguration, params: ['fs.allowed-fallback-filesystems', 'fs.file.limit.input', 'fs.test.limit.output', 'fs.default-scheme', 'fs.hdfs.limit.input', 'fs.hdfs.limit.output', 'fs.test-entropy.limit.total', 'fs.file.limit.output', 'fs.test.limit.input', 'fs.test-entropy.limit.output', 'fs.ftp.limit.total', 'fs.test-entropy.limit.input', 'fs.hdfs.limit.total', 'fs.ftp.limit.output', 'fs.hdfs.limit.stream-timeout', 'fs.file.limit.total', 'fs.test.limit.total', 'fs.ftp.limit.input', 'fs.hdfs.limit.timeout'] , length: 19
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testRecoverWithState, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testCommitAfterRecovery, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testRecoverAfterMultiplePersistsState, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testResumeAfterCommit, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testNoLocalWriteFlag, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testRecoverFromIntermWithoutAdditionalState, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testExceptionWritingAfterCloseForCommit, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testRecoverWithEmptyState, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testCommitAfterNormalClose, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testCloseWithNoData, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testCommitAfterPersist, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableWriterTest_testResumeWithWrongOffset, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopConfigLoadingTest_loadFromEnvVariables, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopConfigLoadingTest_loadFromFlinkConfEntry, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopConfigLoadingTest_loadFromClasspathByDefault, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopConfigLoadingTest_loadOverlappingConfig, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsKindTest_testViewFs, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsKindTest_testS3fileSystemSchemes, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopFreeFsFactoryTest_testHadoopFactoryInstantiationWithoutHadoop, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopFsFactoryTest_testCreateHadoopFsWithoutConfig, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopFsFactoryTest_testCreateHadoopFsWithMissingAuthority, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopDataInputStreamTest_testSeekSkip, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingNonEmptyDirectoryWithSubDirRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingNonEmptyDirectoryDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testMkdirsFailsWithExistingParentFile, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testHomeDirScheme, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testMkdirsReturnsTrueForExistingDirectory, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testWorkDirScheme, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testMkdirsReturnsTrueWhenCreatingDirectory, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testNotExistingFileRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingEmptyDirectoryRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testPathAndScheme, params: ['fs.test.limit.input', 'fs.allowed-fallback-filesystems', 'fs.file.limit.input', 'fs.test.limit.output', 'fs.test-entropy.limit.output', 'fs.default-scheme', 'fs.test-entropy.limit.input', 'fs.test-entropy.limit.total', 'fs.file.limit.output', 'fs.file.limit.total', 'fs.test.limit.total'] , length: 11
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testMkdirsFailsForExistingFile, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingNonEmptyDirectoryRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testNotExistingFileDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingFileDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testFileExists, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingEmptyDirectoryDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testFileDoesNotExist, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testMkdirsCreatesParentDirectories, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopLocalFileSystemBehaviorTest_testExistingFileRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testMkdirsFailsWithExistingParentFile, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingNonEmptyDirectoryWithSubDirRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testNotExistingFileRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testWorkDirScheme, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testFileExists, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingEmptyDirectoryRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testMkdirsCreatesParentDirectories, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testPathAndScheme, params: ['fs.allowed-fallback-filesystems', 'fs.file.limit.input', 'fs.test.limit.output', 'fs.default-scheme', 'fs.hdfs.limit.input', 'fs.hdfs.limit.output', 'fs.test-entropy.limit.total', 'fs.file.limit.output', 'fs.test.limit.input', 'fs.test-entropy.limit.output', 'fs.test-entropy.limit.input', 'fs.hdfs.limit.total', 'fs.file.limit.total', 'fs.test.limit.total'] , length: 14
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingEmptyDirectoryDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testFileDoesNotExist, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testNotExistingFileDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testMkdirsReturnsTrueWhenCreatingDirectory, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testMkdirsReturnsTrueForExistingDirectory, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testHomeDirScheme, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingFileRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testMkdirsFailsForExistingFile, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingNonEmptyDirectoryDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingNonEmptyDirectoryRecursiveDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HdfsBehaviorTest_testExistingFileDeletion, params: [] , length: 0
# method: org.apache.flink.runtime.fs.hdfs.HadoopRecoverableFsDataOutputStreamTest_testDurableWriteOnCommit, params: [] , length: 0
# Number of Configurations :563
# Number of Tests Files Executed :1533
# Number of Tests Files Using Configurations 536
